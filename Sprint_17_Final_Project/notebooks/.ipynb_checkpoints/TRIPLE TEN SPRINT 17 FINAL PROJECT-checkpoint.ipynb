# %%
# Importamos las librerías que vamos a utilizar

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import roc_curve, roc_auc_score, accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.utils import shuffle

from catboost import CatBoostClassifier
import lightgbm as lgb

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense
# Out:
# WARNING:tensorflow:From C:\Users\ZonaDigital\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Cargamos los datasets

contract = pd.read_csv(r'contract.csv')
personal = pd.read_csv(r'personal.csv')
internet = pd.read_csv(r'internet.csv')
phone = pd.read_csv(r'phone.csv')

# %% [markdown]
# ## EDA

# %%
# Imprimimos los tamaños de cada dataset

datasets = [contract,personal,internet,phone]
for i in datasets:
    print(i.shape)
# Out:
# (7043, 8)
# (7043, 5)
# (5517, 8)
# (6361, 2)

# %%
# Imprimimos las columnas de cada dataset para entender como están entrelazados y que datos nos proporcionaran cada set

for i in datasets:
    print(i.columns)
# Out:
# Index(['customerID', 'BeginDate', 'EndDate', 'Type', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges'],
#       dtype='object')
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents'], dtype='object')
# Index(['customerID', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies'],
#       dtype='object')
# Index(['customerID', 'MultipleLines'], dtype='object')

# %%
# Cambiamos el formato de los nombres de las columnas a minúsculas para manipular mejor los datos

for i in datasets:
    i.columns = [j.lower() for j in i.columns]
    print(i.columns)
# Out:
# Index(['customerid', 'begindate', 'enddate', 'type', 'paperlessbilling',
#        'paymentmethod', 'monthlycharges', 'totalcharges'],
#       dtype='object')
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents'], dtype='object')
# Index(['customerid', 'internetservice', 'onlinesecurity', 'onlinebackup',
#        'deviceprotection', 'techsupport', 'streamingtv', 'streamingmovies'],
#       dtype='object')
# Index(['customerid', 'multiplelines'], dtype='object')

# %%
# Comprobamos si tenemos valores duplicados en nuestros datasets usando la columna customerid

for i in datasets:
    print(i.customerid.duplicated().sum())
# Out:
# 0
# 0
# 0
# 0

# %% [markdown]
# **Observaciones Iniciales**
#
# Hemos notado que tenemos conjuntos de datos con mayor cantidad de observaciones que otros. Los conjuntos de datos **contract** y **personal** tienen 7043 observación cada uno mientras que los conjuntos **internet** y **phone** tienen 5517 y 6361 respectivamente. Vamos a averiguar si los datasets contract y personal tiene las mismas observaciones utilizando la columna `customerID`. Y de la misma manera veremos la cantidad de datos faltantes en el dataset con menos observaciones.

# %%
# Comprobamos que tengamos las mismas observaciones en los datasets contract y personal

set(contract['customerid']) - set(personal['customerid'])
# Out:
# set()

# %%
# Analizamos la cantidad de observaciones faltantes entre contract y el dataset con menos observaciones 

len(set(contract['customerid']) - set(internet['customerid']))
# Out:
# 1526

# %%
# Analizamos el porcentaje de datos faltantes en el dataset internet con respecto al dataset contract

'{:.2%}'.format(len(set(contract['customerid']) - set(internet['customerid'])) / contract.shape[0])
# Out:
# '21.67%'

# %% [markdown]
# - Hemos comprobado que tenemos las mismas observaciones en los conjuntos **contract** y **personal**.
# - También hemos visto que tenemos 21.61% menos observaciones en el conjunto **internet** que en los conjuntos de datos más grandes. Esto podría perjudicar nuestro análisis ya que vamos a necesitar la información de estos datasets y si no tenemos la misma cantidad de observaciones necesitaremos decidir qué hacer.
#
# A continuación, analizaremos cada set de datos por separado.

# %% [markdown]
# ### Contract

# %%
# Imprimimos las primeras filas del dataset

contract.head()
# Out:
#    customerid   begindate              enddate            type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
#
#   paperlessbilling              paymentmethod  monthlycharges totalcharges
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65

# %%
# Imprimimos información general de dataset

contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7043 non-null   object
#  1   begindate         7043 non-null   object
#  2   enddate           7043 non-null   object
#  3   type              7043 non-null   object
#  4   paperlessbilling  7043 non-null   object
#  5   paymentmethod     7043 non-null   object
#  6   monthlycharges    7043 non-null   float64
#  7   totalcharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB

# %% [markdown]
# **Observaciones Iniciales**
#
# - Tenemos un conjunto con 8 columnas y 7043 observaciones.
# - A primera vista, no tenemos valores ausentes. Todas las columnas tienen los datos completos para cada observación.
# - Las columnas `begindate`, `enddate`, y `totalcharges` tiene un formato no apto para el tipo de datos que contienen.
# - Vamos a cambiar el tipo de datos a las columnas `begindate` y `totalcharges`. La columna `enddate` será nuestra columna objetivo en la creación de modelos de aprendizaje. Por lo tanto, puede que cambiemos los datos de esta columna a binario, es decir, a 1's y 0's. Más adelante cambiaremos su formato para hacer un pequeño análisis.

# %%
# Convertimos la columna begindate a el formato datetime

contract.begindate = pd.to_datetime(contract['begindate'])

# %%
# Intentamos convertir nuestra columna total charges a formato float

try:
    contract.totalcharges = contract.totalcharges.astype(float)
except:
    print('Unable to convert')
# Out:
# Unable to convert

# %% [markdown]
# Vemos que no hemos podido cambiar el formato aquí usando el método astype(). Esto puede deberse a que en esta columna tenemos datos que no son números. Vamos a probar otro método.

# %%
# Convertimos los datos de la columna a números y llenamos con NaN's aquellos que no podemos cambiar

contract.totalcharges = pd.to_numeric(contract['totalcharges'],errors='coerce')
contract.totalcharges.isna().sum()
# Out:
# 11

# %%
# Elimínanos las observaciones con NaN's

contract.dropna(inplace=True)

# %%
# Verificamos que los cambios se hicieron correctamente. 

contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7032 non-null   object
#  1   begindate         7032 non-null   datetime64[ns]
#  2   enddate           7032 non-null   object
#  3   type              7032 non-null   object
#  4   paperlessbilling  7032 non-null   object
#  5   paymentmethod     7032 non-null   object
#  6   monthlycharges    7032 non-null   float64
#  7   totalcharges      7032 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 494.4+ KB

# %% [markdown]
# #### `begindate`

# %%
# Analizamos la cantidad de inscripciones que hemos tenido por año.

contract.begindate.dt.year.value_counts()
# Out:
# 2019    1957
# 2014    1344
# 2018    1030
# 2015     852
# 2017     845
# 2016     763
# 2020     233
# 2013       8
# Name: begindate, dtype: int64

# %%
# Graficamos las inscripciones por año.

sns.set(style="whitegrid")
sns.histplot(contract.begindate.dt.year, palette='Set2')
plt.title('Subcriptions over the years')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\ZonaDigital\AppData\Local\Temp\ipykernel_5900\2185263362.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(contract.begindate.dt.year, palette='Set2')

# %%
# Meses del año 2013

contract[contract['begindate'].dt.year == 2013]['begindate'].dt.month.value_counts()
# Out:
# 10    3
# 12    3
# 11    2
# Name: begindate, dtype: int64

# %%
# Meses del año 2020

contract[contract['begindate'].dt.year == 2020]['begindate'].dt.month.value_counts()
# Out:
# 1    233
# Name: begindate, dtype: int64

# %% [markdown]
# **Obervaciones**
#
# - Tenemos datos desde el año 2013 hasta el año 2020
# - Hemos creado un gráfico de cantidad de personas que adquieren planes por año. Esto nos permite ver que tanto se ha aumentado o disminuido la adquisición de clientes a lo largo de los anos.
# - El mejor año para la empresa en cuestión de cantidad de clientes adquiridos ha sido el año 2019 hasta el momento con 1957.
# - Solo tenemos información desde octubre hasta diciembre del año 2013
# - Solo tenemos información del mes de enero del año 2020.

# %% [markdown]
# #### `enddate`

# %%
# Creamos un nuevo dataset con la columna enddate y convertimos a datetime para poder hacer un análisis

end_date = contract[contract['enddate'] != 'No']
end_date.enddate = pd.to_datetime(end_date.enddate)
end_date.enddate.dt.year.value_counts()
# Out:
# C:\Users\ZonaDigital\AppData\Local\Temp\ipykernel_5900\1911925666.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   end_date.enddate = pd.to_datetime(end_date.enddate)
# 2019    1409
# 2020     460
# Name: enddate, dtype: int64

# %%
# Meses del ano 2019

end_date[end_date['enddate'].dt.year == 2019]['enddate'].dt.month.unique()
# Out:
# array([12, 11, 10], dtype=int64)

# %%
# Meses del ano 2020

end_date[end_date['enddate'].dt.year == 2020]['enddate'].dt.month.unique()
# Out:
# array([1], dtype=int64)

# %%
# Graficamos la cantidad de personas que terminan sus planes con nosotros 

end_date.enddate.dt.year.value_counts().plot(kind='bar',color=['lightblue','lightgreen'])
plt.title('End Date Per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
# Graficamos la cantidad de personas que terminan sus planes con nosotros por mes

print(end_date.enddate.dt.month.value_counts())

end_date['month'] = end_date.enddate.dt.month
sns.countplot(x=end_date.month, palette='Set2')
plt.title('End Date Per Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()
# Out:
# 11    485
# 12    466
# 1     460
# 10    458
# Name: enddate, dtype: int64
# C:\Users\ZonaDigital\AppData\Local\Temp\ipykernel_5900\1892814328.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   end_date['month'] = end_date.enddate.dt.month

# %%
# Datos de personas cancelando sus planes

(end_date.enddate - end_date.begindate).dt.days.describe()
# Out:
# count    1869.000000
# mean      547.352060
# std       594.389607
# min        30.000000
# 25%        61.000000
# 50%       304.000000
# 75%       883.000000
# max      2191.000000
# dtype: float64

# %%
# Cuantas personas han cancelado en menos de un ano? 

((end_date.enddate - end_date.begindate).dt.days < 365).sum()
# Out:
# 999

# %%
# Calculamos el churn rate

print('Churn Rate 2019')
print('{:.2%}'.format(len(end_date[end_date['enddate'].dt.year == 2019])/len(contract[contract['begindate'].dt.year == 2019])))
# Out:
# Churn Rate 2019
# 72.00%

# %%
print('Churn Rate 2020')
print('{:.2%}'.format(len(end_date[end_date['enddate'].dt.year == 2020])/len(contract[contract['begindate'].dt.year == 2020])))
# Out:
# Churn Rate 2020
# 197.42%

# %% [markdown]
# **Observaciones**
#
# - Vemos que las personas han empezado a cancelar los planes desde Octubre del 2019.
# - Vemos que los meses con mayor número de cancelaciones son los tres últimos y el primer mes de año. Siendo noviembre y diciembre los meses con mayor cantidad de cancelaciones.
# - El mes de Enero de este ano ya supera en cancelaciones al mes de Octubre del ano pasado.
# - Vemos también que tenemos personas que han cancelado teniendo solo 30 días el servicio y hasta personas que han tenido hasta 6 años con nosotros. En promedio las personas cancelan después de los 1.5 años.
# - Tenemos casi 100 personas que han cancelado en menos de un año.
# - Tuvimos una tasa de pérdida de clientes del 72% el año 2019 y estamos teniendo una tasa mucho más elevada lo que lleva de este año.

# %% [markdown]
# #### `type`

# %%
# Buscamos los valores únicos de esta columna para asegurarnos que no haya valores extraños

contract.type.unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
# Vemos la proporción de cada uno de ellas

contract.type.value_counts(normalize=True)
# Out:
# Month-to-month    0.551052
# Two year          0.239619
# One year          0.209329
# Name: type, dtype: float64

# %%
# Creamos un gráfico para ver la proporción de tipos de contratos en general

plt.figure(figsize=(10,4))
contract.type.value_counts(normalize=True).plot(
    kind='pie',autopct='%1.1f%%',colors = ['lightblue', 'lightgreen', 'lightcoral']
)
plt.title('Contract Type Pie Chart')
plt.show()

# %%
# Creamos un gráfico para entender la preferencia de tipos contrato a lo lago de los anos. 

contract['year'] = contract.begindate.dt.year
contract.pivot_table(values='enddate',index='year',columns='type',aggfunc='count').plot(
    kind='bar', color =['lightblue', 'lightgreen', 'lightcoral'])
plt.title('Contract Type Per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Observaciones**
#
# - Tenemos tres tipos de planes; anual, de dos años, y mensual.
# - El 55% de nuestros clientes prefieren el pago mes a mes
# - Vemos que la cantidad de planes mensuales a aumentado con el paso de los anos mientras que los contratos de uno y dos años han disminuido. Esto hace más sencillo que las personas puedan cancelar sus planes.

# %% [markdown]
# #### `paperlessbilling`

# %%
# Buscamos los valores únicos para verificar que no tengamos valores extraños

contract.paperlessbilling.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
# Imprimimos la proporción de los valores de esta columna

contract.paperlessbilling.value_counts(normalize=True)
# Out:
# Yes    0.592719
# No     0.407281
# Name: paperlessbilling, dtype: float64

# %%
# Creamos un gráfico para ver la proporción

sns.countplot(x = contract.paperlessbilling, data=contract,palette='Set2')
plt.title('Paperlessbilling Histogram')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
contract.pivot_table(values='enddate',index='year',columns='paperlessbilling',aggfunc='count').plot(
    kind='bar', color=['#FFA07A','lightgreen'])
plt.title('Contract Type Per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Obervaciones**
#
# - Tenemos una columna de valores binarios, SI y NO.
# - Graficamos la proporción de esta variable y vemos que el 59.27% de nuestros clientes prefieren pago con facturacion electronica.
# - También podemos observar que la cantidad de clientes que prefieren facturación electrónica han ido aumentando al igual que los que no prefieren este tipo de facturación.

# %% [markdown]
# `payment method`

# %%
# Imprimimos los valores únicos de esta columna para asegurarnos de no tener valores extraños

contract.paymentmethod.unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
# Imprimimos la proporción de cada método de pago

contract.paymentmethod.value_counts(normalize=True)
# Out:
# Electronic check             0.336320
# Mailed check                 0.228100
# Bank transfer (automatic)    0.219283
# Credit card (automatic)      0.216297
# Name: paymentmethod, dtype: float64

# %%
# Creamos un grafico para observar la proporción

plt.figure(figsize=(10,4))
contract.paymentmethod.value_counts(normalize=True).plot(
    kind='pie',colors=['lightgreen','#FFA07A','lightblue','lightcoral'],autopct='%1.1f%%')
plt.title('Payment Method Pie')
plt.ylabel('')
plt.show()

# %%
contract.pivot_table(values='enddate',index='year',columns='paymentmethod',aggfunc='count').plot(
    kind='bar',color=['lightgreen','#FFA07A','lightblue','lightcoral'])
plt.title('Payment Method Per Year')
plt.xlabel('Method')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Observaciones**
#
# - Tenemos cuatro diferentes métodos de pago; Transferencia bancaria, tarjeta de crédito, cheque electrónico, y cheque vía email. Los dos primeros métodos mencionados son métodos automáticos.
# - El 33.6% de los usuarios prefieren pagar a través de cheque electrónico.
# - Vemos que, a lo largo de los anos, los contratos con métodos de pago automáticos han ido disminuyendo mientras que los contratos con pagos no automáticos han aumentado.

# %% [markdown]
# `monthlycharges`

# %%
# Definimos un fórmula para analizar outliers 

def outliers(df,col,ylabel=None):
    df.boxplot(col,figsize=(8,5))
    plt.title('Boxplot of ' + col)
    plt.ylabel(ylabel)
    plt.show()

    min = df[col].min()
    values_0 = len(df[df[col] <= 0])
    percentage_values_0 = '{:.2%}'.format(len(df[df[col] <= 0])/len(df))

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    up_limit = Q3 + IQR
    low_limit = Q1 - IQR

    values_up_limit = len(df[df[col] >= up_limit])
    values_low_limit = len(df[df[col] <= low_limit])

    percentage_up_limit = '{:.2%}'.format(len(df[df[col] >= up_limit])/len(df))
    percentage_low_limit = '{:.2%}'.format(len(df[df[col] <= low_limit])/len(df))

    print(df[col].describe())
    print()
    print(f'El IQR de {col} es {IQR}')
    print()
    
    print(f'EL limite inferior de nuestro boxplot es {low_limit}')
    print()
    print(f'La cantidad de valores iguales o menores a {low_limit} es {values_low_limit}')
    print()
    print(f'El porcentaje de valores iguales o menores a {low_limit} es {percentage_low_limit}')

    print()
    print(f'EL limite superior es de nuestro boxplot es {up_limit}')
    print()
    print(f'La cantidad de volores iguales o superiores a {up_limit} es {values_up_limit}')
    print()
    print(f'Elporcentaje de valores iguales o superiores a {up_limit} es {percentage_up_limit}')

# %%
# Buscamos outliers 

outliers(contract,'monthlycharges')
# Out:
# count    7032.000000
# mean       64.798208
# std        30.085974
# min        18.250000
# 25%        35.587500
# 50%        70.350000
# 75%        89.862500
# max       118.750000
# Name: monthlycharges, dtype: float64
#
# El IQR de monthlycharges es 54.275
#
# EL limite inferior de nuestro boxplot es -18.6875
#
# La cantidad de valores iguales o menores a -18.6875 es 0
#
# El porcentaje de valores iguales o menores a -18.6875 es 0.00%
#
# EL limite superior es de nuestro boxplot es 144.1375
#
# La cantidad de volores iguales o superiores a 144.1375 es 0
#
# Elporcentaje de valores iguales o superiores a 144.1375 es 0.00%

# %%
sns.histplot(contract.monthlycharges)
# Out:
# <Axes: xlabel='monthlycharges', ylabel='Count'>

# %%
# Creamos un grafico para ver el precio promedio de los planes por ano

fig, axs = plt.subplots(1,2, figsize=(16,5))
contract.pivot_table(values='monthlycharges',index='year',aggfunc='mean').plot(kind='bar',ax=axs[0], color='lightblue')
axs[0].set_title('Montly Charges Mean Per Year')
axs[0].set_xlabel('Year')
axs[0].set_ylabel('Mean Charges')

# Creamos un grafico para ver el ingreso de los planes por ano


contract.pivot_table(values='monthlycharges',index='year',aggfunc='sum').plot(kind='bar',ax=axs[1],color='lightgreen')
plt.title('Montly Charges Sum Per Year')
plt.xlabel('Year')
plt.ylabel('Sum Charges')
plt.show()

# %%
# Creamos un grafico para ver el precio promedio de cada tipo de plan por ano

contract.pivot_table(values='monthlycharges',index='year',columns='type',aggfunc='mean').plot(
    kind='bar',color=['lightblue', 'lightgreen', 'lightcoral'])
plt.title('Montly Charges Sum Per Year')
plt.xlabel('Year')
plt.ylabel('Sum Charges')
plt.show()

# %% [markdown]
# **Observaciones**
#
# - En promedio las personas pagan 64 dólares por plan.
# - Los pagos mensuales van desde los 18.25 dolares hasta 118.75.
# - No tenemos valores que sean considerados atípicos en esta columna.
# - Podemos ver en nuestros gráficos que el promedio del precio de los planes ha disminuido. Esto puede deberse a que las personas tienen planes con menos beneficios o que el precio simplemente ha disminuido.
# - A pesar de que los precios por plan han disminuido a lo largo de los anos las ganancias han aumentado desde el 2016.
# - Vemos que también que el precio ha disminuido en todos los distintos tipos de planes.

# %% [markdown]
# `totalcharges`

# %%
# Analizamos posibles valores atípicos 

outliers(contract,'totalcharges')
# Out:
# count    7032.000000
# mean     2283.300441
# std      2266.771362
# min        18.800000
# 25%       401.450000
# 50%      1397.475000
# 75%      3794.737500
# max      8684.800000
# Name: totalcharges, dtype: float64
#
# El IQR de totalcharges es 3393.2875000000004
#
# EL limite inferior de nuestro boxplot es -2991.8375000000005
#
# La cantidad de valores iguales o menores a -2991.8375000000005 es 0
#
# El porcentaje de valores iguales o menores a -2991.8375000000005 es 0.00%
#
# EL limite superior es de nuestro boxplot es 7188.025000000001
#
# La cantidad de volores iguales o superiores a 7188.025000000001 es 272
#
# Elporcentaje de valores iguales o superiores a 7188.025000000001 es 3.87%

# %%
# Creamos un grafico de total charges por ano. 

contract.pivot_table(values='totalcharges',index='year',aggfunc='sum').plot(kind='bar',color='lightcoral')
plt.title('Total Charges Sum Per Year')
plt.xlabel('Year')
plt.ylabel('Sum Charges')
plt.show()

# %% [markdown]
# **Observaciones**
#
# - En promedio los pagos anuales poc cliente son de 2283.30 dolares
# - Prácticamente no tenemos outliers en esta columna. Solo tenemos un 3.87% de valores mayores a nuestro límite superior.
# - Vemos que a lo largo de los anos la suma de valores totales cobrados a los clientes por ano ha disminuido. Esto puede deberse a la cancelación de los contratos con tan poco tiempo. Ya vimos que tenemos clientes que han estado con nosotros menos de un ano. Esto disminuye el valor de esta columna.

# %% [markdown]
# ### Personal

# %%
# Imprimimos las primeras filas de este dataset

personal.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No

# %%
# Imprimimos un info para conocer los tipos de datos y valores ausentes.

personal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerid     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   seniorcitizen  7043 non-null   int64
#  3   partner        7043 non-null   object
#  4   dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Imrpimimos un describe()

personal.describe(include='all')
# Out:
#         customerid gender  seniorcitizen partner dependents
# count         7043   7043    7043.000000    7043       7043
# unique        7043      2            NaN       2          2
# top     7590-VHVEG   Male            NaN      No         No
# freq             1   3555            NaN    3641       4933
# mean           NaN    NaN       0.162147     NaN        NaN
# std            NaN    NaN       0.368612     NaN        NaN
# min            NaN    NaN       0.000000     NaN        NaN
# 25%            NaN    NaN       0.000000     NaN        NaN
# 50%            NaN    NaN       0.000000     NaN        NaN
# 75%            NaN    NaN       0.000000     NaN        NaN
# max            NaN    NaN       1.000000     NaN        NaN

# %% [markdown]
# **Observaciones Iniciales**
#
# - Tenemos un conjunto de datos con 7043 observaciones y 5 columnas.
# - Aparentemente no tenemos valores ausentes.
# - Los tipos de datos de cada columna parecen estar correctos.
# - La mayoría de las columnas contienen information binaria.

# %%
# Imprimimos los valores de esta columna

personal.seniorcitizen.unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# Con esto comprobamos que la columna `seniorcitizen` también tiene valores binarios. Esto hara mas facil nuestro analisis de estas columnas.

# %%
# Creamos gráficos para cada columna

fig, axs = plt.subplots(2, 2, figsize=(16, 10))

for i, ax_row in enumerate(axs):
    for j, ax in enumerate(ax_row):
        subplot_index = i * 2 + j
        if subplot_index < len(personal.columns) - 1:
            column_index, column_name = subplot_index, personal.drop(columns='customerid').columns[subplot_index]
            sns.countplot(x=personal[column_name],data=personal, ax=ax,palette='Set2')
            ax.set_title(f'Histogram {column_name}')
            
            total_count = len(personal)
            counts = personal[column_name].value_counts()
            for patch in ax.patches:
                height = patch.get_height()
                percentage = height / total_count * 100
                ax.annotate(f'{percentage:.1f}%', (patch.get_x() + patch.get_width() / 2, height),
                            ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observaciones**
#
# - Tenemos un conjunto de datos con 7043 observaciones y 5 columnas.
# - Todas las columnas tiene valores binarios excepto la de `customerid`
# - Hemos creado hisplots para cada columna para entender la proporción de cada elemento.
# - En nuestra columna `gender`de genero vemos que el 50.5% de nuestros clientes son hombres.
# - En nuestra columna `seniorcitizen` vemos que el 83.8% de nuestros clientes no son de la tercera edad.
# - En nuestra columna `partner` vemos que 51.7% de nuestros clientes no estan casados.
# - En nuestra columna `dependets` vemos que 70% de nuestros clientes no tienen hijos o dependientes.

# %% [markdown]
# ### Internet

# %%
# Imprimimos las primeras columnas de nuestro dataset

internet.head()
# Out:
#    customerid internetservice onlinesecurity onlinebackup deviceprotection  \
# 0  7590-VHVEG             DSL             No          Yes               No
# 1  5575-GNVDE             DSL            Yes           No              Yes
# 2  3668-QPYBK             DSL            Yes          Yes               No
# 3  7795-CFOCW             DSL            Yes           No              Yes
# 4  9237-HQITU     Fiber optic             No           No               No
#
#   techsupport streamingtv streamingmovies
# 0          No          No              No
# 1          No          No              No
# 2          No          No              No
# 3         Yes          No              No
# 4          No          No              No

# %%
# Imprimimos la información del dataset para chequear tipo de datos y valores ausentes.

internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        5517 non-null   object
#  1   internetservice   5517 non-null   object
#  2   onlinesecurity    5517 non-null   object
#  3   onlinebackup      5517 non-null   object
#  4   deviceprotection  5517 non-null   object
#  5   techsupport       5517 non-null   object
#  6   streamingtv       5517 non-null   object
#  7   streamingmovies   5517 non-null   object
# dtypes: object(8)
# memory usage: 344.9+ KB

# %%
# Imprimimos un describe

internet.describe(include='all')
# Out:
#         customerid internetservice onlinesecurity onlinebackup  \
# count         5517            5517           5517         5517
# unique        5517               2              2            2
# top     7590-VHVEG     Fiber optic             No           No
# freq             1            3096           3498         3088
#
#        deviceprotection techsupport streamingtv streamingmovies
# count              5517        5517        5517            5517
# unique                2           2           2               2
# top                  No          No          No              No
# freq               3095        3473        2810            2785

# %%
# Creamos gráficos para cada columna

fig, axs = plt.subplots(4, 2, figsize=(16, 15))

for i, ax_row in enumerate(axs):
    for j, ax in enumerate(ax_row):
        subplot_index = i * 2 + j
        if subplot_index < len(internet.columns) - 1:
            column_index, column_name = subplot_index, internet.drop(columns='customerid').columns[subplot_index]
            sns.countplot(x=internet[column_name], ax=ax, palette='Set2')
            ax.set_title(f'Histogram {column_name}')
            
            total_count = len(internet)
            counts = internet[column_name].value_counts()
            for patch in ax.patches:
                height = patch.get_height()
                percentage = height / total_count * 100
                ax.annotate(f'{percentage:.1f}%', (patch.get_x() + patch.get_width() / 2, height),
                            ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observaciones**
#
# - Tenemos un conjunto de datos con 5517 muestras y 8 columnas. Tenemos menos muestras que en nuestros datasets anteriores.
# - Todas nuestras columnas, excepto la columna `customerid` son binarias.
# - Hemos credo graficos para cada variable para entender un poco mas su distribucion.
# - En nuestra columna `internetservice` vemos que que 56.1% nuestros clientes prefieren fibra optica.
# - En nuestra columna `onlinesecurity` vemos que el 63.4% de nuestros clientes no tienen este servicio.
# - En nuestra columna `onlinebackup` vemos que el 56.0% de nuestros clientes no tiene este servicio.
# - En nuestra columna `deviceprotection` vemos que el 56.1% de nuestros clientes no tiene este servicio.
# - En nuestra columna `techsupport` vemos que el 63.0% de nuestros clientes no tiene este servicio.
# - En nuestra columna `stramingtv` vemos que el 50.9% de nuestros clientes no tiene este servicio.
# - En nuestra columna `streamingmovies` vemos que el 50.5% de nuestros clientes no tiene este servicio.

# %% [markdown]
# ### Phone

# %%
# Imprimimos las primeras filas de nuestro dataset

phone.head()
# Out:
#    customerid multiplelines
# 0  5575-GNVDE            No
# 1  3668-QPYBK            No
# 2  9237-HQITU            No
# 3  9305-CDSKC           Yes
# 4  1452-KIOVK           Yes

# %%
# Imprimimos información para analizar datos faltantes y tipos de datos de las columnas

phone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerid     6361 non-null   object
#  1   multiplelines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB

# %%
# Imprimimos un describe

phone.describe(include='all')
# Out:
#         customerid multiplelines
# count         6361          6361
# unique        6361             2
# top     5575-GNVDE            No
# freq             1          3390

# %%
# Imprimimos la distribución de nuestra variable multiplelines

phone.multiplelines.value_counts(normalize=True)
# Out:
# No     0.532935
# Yes    0.467065
# Name: multiplelines, dtype: float64

# %%
# Creamos un gráfico para visualizar la distribución
sns.countplot(x=phone['multiplelines'],palette='Set2')
plt.title('Multiple Lines Count Plot')
plt.show()

# %% [markdown]
# **Observaciones**
#
# - Tenemos un conjunto de datos con 6361 observaciones y 2 columnas.
# - La columna `multiplelines` es binaria.
# - Hemos analizado su proporción y hemos creado un gráfico para poder visualizarlo. El 53.29% de nuestros clientes no tiene líneas múltiples.
# - Vemos que este conjunto de datos tiene menos observaciones que los dos primeros. Esto puede deberse a que no todos los clientes tengan línea telefónica en su plan.

# %% [markdown]
# ### Observaciones EDA

# %% [markdown]
# Hemos analizado cada conjunto por separado para llegar a entender mejor todos los datos que poseemos para poder prepararnos mejor para nuestra tarea de creación de modelos de aprendizaje automático. Algunos de los hallazgos importantes para la tarea son:
#
# - Tenemos cuatro datasets con información pertinente a los mismos clientes.
# - No todos los conjuntos de datos tiene la misma cantidad de muestras.
# - Nuestra variable objetivo tiene fechas de finalización de contrato. Nuestro objetivo es detectar si un cliente va a cancelar o no. No necesitamos estas fechas.
# - Tenemos varias variables binarias categóricas(Yes/No).
# - Nuestra variable objetivo no esta balanceada.
#
# **Siguientes pasos**
#
# - Tenemos que unir nuestros datasets en uno solo.
# - Podríamos hacer un nuevo análisis exploratorio con el nuevo dataset.
# - Tendremos que limpiar el nuevo dataset para que no contenga datos duplicados o valores ausentes.
# - Tendremos que preparar nuestro dataset para el entrenamiento de modelos. Ya que tenemos algunas variables categóricas, tendremos que decidir que hacer con estas columnas. Podríamos utilizar el algoritmo one-hot-ecoder para hacer la transformación de datos.
# - Ya que nuestra variable objetivo se encuentra desbalanceada, también tenemos que decidir la manera de balancear nuestro dataset antes del entrenamiento. El metodo pensado para esto puede ser el sobremuestreo.
# - Entrenaremos 6 modelos distintos y encontraremos el que tenga los mejores resultados.
# - Realizaremos un informe con nuestros resultados.
#
# ### Union de datasets

# %%
# Unimos todos nuestros datasets en uno solo

final_df = contract.merge(personal,how='inner').merge(internet,how='left').merge(phone,how='left')

# Imprimimos las primeras filas de nuestro nuevo dataset
final_df.head()
# Out:
#    customerid  begindate              enddate            type  \
# 0  7590-VHVEG 2020-01-01                   No  Month-to-month
# 1  5575-GNVDE 2017-04-01                   No        One year
# 2  3668-QPYBK 2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW 2016-05-01                   No        One year
# 4  9237-HQITU 2019-09-01  2019-11-01 00:00:00  Month-to-month
#
#   paperlessbilling              paymentmethod  monthlycharges  totalcharges  \
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65
#
#    year  gender  ...  partner dependents internetservice onlinesecurity  \
# ...

# %%
# Imprimimos informacion general de nuestro dataset

final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7032 non-null   object
#  1   begindate         7032 non-null   datetime64[ns]
#  2   enddate           7032 non-null   object
#  3   type              7032 non-null   object
#  4   paperlessbilling  7032 non-null   object
#  5   paymentmethod     7032 non-null   object
#  6   monthlycharges    7032 non-null   float64
#  7   totalcharges      7032 non-null   float64
#  8   year              7032 non-null   int64
#  9   gender            7032 non-null   object
#  10  seniorcitizen     7032 non-null   int64
#  11  partner           7032 non-null   object
#  12  dependents        7032 non-null   object
#  13  internetservice   5512 non-null   object
#  14  onlinesecurity    5512 non-null   object
#  15  onlinebackup      5512 non-null   object
# ...

# %%
# Buscamos duplicados en nuestro dataset

final_df.customerid.duplicated().sum()
# Out:
# 0

# %%
# Comprobamos que tengamos todas muestras originales comparando con el dataset contract

len(set(final_df.customerid) - set(contract.customerid))
# Out:
# 0

# %% [markdown]
# **Observaciones**
#
# - Al unir todos los dataset conseguimos un dataset con 7032 muestras y 21 variables o columnas.
# - Hemos buscado duplicados de las muestras y no hemos encontrado nada.
# - Al unir todos los dataset se han generado columnas con valores ausentes. Esto se debe a que las personas no consumen todos los servicios ofrecidos. Vamos a remplazar todos los valores nulos para que no nos afecten en la creación de modelos.
# - Cambiamos todos los datos de fechas en la columna `enddate` a 'Si'.

# %%
# Llenamos los valores ausentes en las respectivas columnas

fillna_columns = list(internet.drop(columns=['customerid','internetservice']).columns)

final_df[['multiplelines','internetservice']] = final_df[['multiplelines','internetservice']].fillna('NA')

final_df[fillna_columns] = final_df[fillna_columns].fillna('No')

# %%
# Cambiamos todos los datos de fechas en la columna `enddate` a 'Si'.

final_df.enddate = final_df.enddate.apply(lambda x: 'Yes' if x != 'No' else 'No')

# %%
# Comprobamos no tener más valores ausentes

final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7032 non-null   object
#  1   begindate         7032 non-null   datetime64[ns]
#  2   enddate           7032 non-null   object
#  3   type              7032 non-null   object
#  4   paperlessbilling  7032 non-null   object
#  5   paymentmethod     7032 non-null   object
#  6   monthlycharges    7032 non-null   float64
#  7   totalcharges      7032 non-null   float64
#  8   year              7032 non-null   int64
#  9   gender            7032 non-null   object
#  10  seniorcitizen     7032 non-null   int64
#  11  partner           7032 non-null   object
#  12  dependents        7032 non-null   object
#  13  internetservice   7032 non-null   object
#  14  onlinesecurity    7032 non-null   object
#  15  onlinebackup      7032 non-null   object
# ...

# %%
# Comprobamos el cambio de nuestros datos en la columna enddate

final_df.enddate.head()
# Out:
# 0     No
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# Name: enddate, dtype: object

# %% [markdown]
# #### EDA final_df

# %%
# Imprimimos unas filas del dataset

final_df_copy = final_df.copy()
final_df_copy.head()
# Out:
#    customerid  begindate enddate            type paperlessbilling  \
# 0  7590-VHVEG 2020-01-01      No  Month-to-month              Yes
# 1  5575-GNVDE 2017-04-01      No        One year               No
# 2  3668-QPYBK 2019-10-01     Yes  Month-to-month              Yes
# 3  7795-CFOCW 2016-05-01      No        One year               No
# 4  9237-HQITU 2019-09-01     Yes  Month-to-month              Yes
#
#                paymentmethod  monthlycharges  totalcharges  year  gender  ...  \
# 0           Electronic check           29.85         29.85  2020  Female  ...
# 1               Mailed check           56.95       1889.50  2017    Male  ...
# 2               Mailed check           53.85        108.15  2019    Male  ...
# 3  Bank transfer (automatic)           42.30       1840.75  2016    Male  ...
# 4           Electronic check           70.70        151.65  2019  Female  ...
#
#    partner dependents internetservice onlinesecurity onlinebackup  \
# ...

# %%
# Creamos una columna con la cantidad de servicios por cliente

service_columns = ['internetservice', 'onlinesecurity', 'onlinebackup', 'deviceprotection', 
                   'techsupport', 'streamingtv', 'streamingmovies', 'multiplelines']

final_df_copy['totalservices'] = final_df_copy[service_columns].apply(lambda row: sum(row == 'Yes'), axis=1)

# %%
# Analizamos la distribución de totalservices

final_df_copy.totalservices.value_counts(normalize=True)
# Out:
# 0    0.236490
# 1    0.164391
# 3    0.139078
# 2    0.136092
# 4    0.132395
# 5    0.102247
# 6    0.059727
# 7    0.029579
# Name: totalservices, dtype: float64

# %%
# Creamos un gráfico para analizar la distribución de totalservices

sns.countplot(x=final_df_copy.totalservices,palette='Set2')
plt.title('Total Services Count Plot')
plt.show()

# %%
# Creamos un gráfico para analizar el promedio de totalservices por año.

final_df_copy.pivot_table(values='totalservices',index='year',aggfunc='mean').plot(kind='bar',color='#FFA07A')
plt.title('Total Services Sum Per Year')
plt.xlabel('Year')
plt.ylabel('Mean')
plt.show()

# %%
# Creamos un gráfico de distribución de servicios para las personas que han cancelado

sns.countplot(x=final_df_copy[final_df_copy['enddate'] == 'Yes'].totalservices,palette='Set2')
plt.title('Total Services EndDate Yes')
plt.show()

# %%
# Creamos un gráfico para analizar el tipo de servicio de internet por año.

final_df.pivot_table(
    index='year',columns=['internetservice'],values='monthlycharges',aggfunc='count').plot(
    kind='bar',color=['lightblue','#FFA07A','lightgreen'])
plt.title('Internet Service per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
# Creamos un gráfico para analizar la cantidad de líneas telefónicas por cliente por año.

final_df.pivot_table(
    index='year',columns='multiplelines',values='monthlycharges',aggfunc='count').plot(
    kind='bar',color=['#FFA07A','lightcoral','lightgreen'])
plt.title('Internet Service per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
# Creamos una matriz de correlación

final_df_copy.corr()
# Out:
# C:\Users\ZonaDigital\AppData\Local\Temp\ipykernel_5900\419968276.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   final_df_copy.corr()
#                 monthlycharges  totalcharges      year  seniorcitizen  \
# monthlycharges        1.000000      0.651065 -0.263086       0.219874
# totalcharges          0.651065      1.000000 -0.819304       0.102411
# year                 -0.263086     -0.819304  1.000000      -0.027386
# seniorcitizen         0.219874      0.102411 -0.027386       1.000000
# totalservices         0.773098      0.787082 -0.525341       0.095516
#
#                 totalservices
# monthlycharges       0.773098
# totalcharges         0.787082
# year                -0.525341
# seniorcitizen        0.095516
# totalservices        1.000000

# %%
# Creamos un gráfico para entender la correlación de nuestras variables

corr = final_df_copy.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True), square=True)
# Out:
# C:\Users\ZonaDigital\AppData\Local\Temp\ipykernel_5900\817281128.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = final_df_copy.corr()
# C:\Users\ZonaDigital\AppData\Local\Temp\ipykernel_5900\817281128.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True), square=True)
# <Axes: >

# %% [markdown]
# **Observaciones EDA full_df**
#
# - En esta sección creamos una nueva columna que nos indicaba la cantidad de servicios que cada persona tenía en su contrato.
# - Descubrimos que la mayoría de nuestros clientes, en este caso el 23.64% de ellos solo tiene una línea telefónica. El porcentaje disminuye a medida que aumenta la cantidad de servicios.
# - Creamos un gráfico para mostrar el promedio de servicios por año. Descubrimos que en promedio la cantidad de servicios contratados por cliente ha disminuido desde 2014.
# - También creamos un gráfico para analizar la cantidad de servicios contratados por las personas que terminaron sus contratos. Las personas que terminaron sus contratos tenían entre 0 y 7 servicios. (0 significa que solo tenían una línea telefónica)
# - Creamos un gráfico para analizar cómo ha incrementado o disminuido cada tipo de servicio de internet por año. Descubrimos que cada servicio a aumentado de manera proporcional a como han aumentado la cantidad de usuarios. Siendo el internet de fibra óptica el de mayor contratación. También vemos que la cantidad de personas que no contrata el servicio de internet ha ido aumentando.
# - Creamos un gráfico para analizar las líneas telefónicas por cliente por año. Descubrimos que la cantidad de personas que solo tienen una línea telefónica ha ido aumentando con el paso de los anos.
# - Creamos un gráfico de correlación. Descubrimos que las variables `monthlycharges` y `totalcharges` están positivamente correlacionadas. También vemos que `totalservices` también esta positivamente correlacionada con cada una de estas variables antes mencionadas.

# %% [markdown]
# **Siguientes pasos**
# - En nuestro analisis exploratorio vimos que nuestra variable objetivo estaba desbalanceada. Esto podria afectar el rendimiento de nuestros modelos. Podriamos usar varios metodos para balancear nuestro dataset. Para este projecto usaremos el metodo de sobremuestro.
# - Ya hemos notado que tenemos varias columnas categoricas que necesitan ser codificadas para algunos de nuestros modelos. Vamos a utilizar el algoritmo OHE para codificar todas nuestras variable categoricas y asi entrenar nuestros modelos.
#
# **Modelos a entrenar**
#
# - Dummy
# - Logistic Regression
# - Decision Tree
# - Random Forest
# - LightGBM
# - CatBoost
# - Neural Networks

# %% [markdown]
# ## Preparacion de los datos

# %%
# Elimínanos la columna year de nuestro dataset

final_df = final_df.drop(columns='year',axis=1)

# %%
# Usamos el método OHE para codificar nuestras columnas categóricas.

ohe_columns = final_df.drop(columns=['customerid','begindate','seniorcitizen','monthlycharges','totalcharges']).columns
final_df_ohe = pd.get_dummies(final_df,columns=ohe_columns,drop_first=True)
final_df_ohe.head()
# Out:
#    customerid  begindate  monthlycharges  totalcharges  seniorcitizen  \
# 0  7590-VHVEG 2020-01-01           29.85         29.85              0
# 1  5575-GNVDE 2017-04-01           56.95       1889.50              0
# 2  3668-QPYBK 2019-10-01           53.85        108.15              0
# 3  7795-CFOCW 2016-05-01           42.30       1840.75              0
# 4  9237-HQITU 2019-09-01           70.70        151.65              0
#
#    enddate_Yes  type_One year  type_Two year  paperlessbilling_Yes  \
# 0            0              0              0                     1
# 1            0              1              0                     0
# 2            1              0              0                     1
# 3            0              1              0                     0
# 4            1              0              0                     1
#
#    paymentmethod_Credit card (automatic)  ...  internetservice_Fiber optic  \
# ...

# %%
# Creamos una semilla
random_state = 12345

# Dividimos nuestros datos en target y features

features_ohe = final_df_ohe.drop(columns=['enddate_Yes','customerid','begindate'])
target_ohe = final_df_ohe.enddate_Yes

# %%
# Dividimos nuestros datasets en entrenamiento y prueba

features_train_ohe, features_test_ohe, target_train_ohe, target_test_ohe = train_test_split(
    features_ohe, target_ohe, test_size=0.2,random_state=random_state)

# %%
# Creamos una función que nos permitirá graficar las métricas de nuestros modelos

def get_roc_plot_data(y, predictions):
    fpr, tpr, _ = roc_curve(y,
                            predictions,
                            pos_label=None,
                            drop_intermediate=True)
    auc = round(roc_auc_score(y, predictions), 5)

    return fpr, tpr, auc


def plot_roc(custom_axis, y, predictions):

    multiple_curves = isinstance(y, dict)

    custom_axis.axis([-0.01,1.01,0,1.01])
    custom_axis.set(xlabel="False Positive Rate", ylabel="Recall")
    custom_axis.set_title("ROC Curve")

    if not multiple_curves:
        fpr, tpr, auc = get_roc_plot_data(y, predictions)

        custom_axis.plot(fpr, tpr)
        custom_axis.text(0.65, 0.02, 'AUC: ' + str(auc), fontsize=12)
    else:
        for i in range(len(y)):
            model = list(y.keys())[i]
            fpr, tpr, auc = get_roc_plot_data(y[model], predictions[model])

            custom_axis.plot(fpr, tpr, label=model)
            custom_axis.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
            custom_axis.text(0.50, 0.02 + i*0.1, f"{model} AUC: {str(auc)}", fontsize=12)

    custom_axis.plot([0,1],[0,1])

    return []

# %% [markdown]
# ## Modelos
# ### Dummy

# %%
# Creamos un modelo Dummy

model = DummyClassifier(strategy='most_frequent')
model.fit(features_train_ohe, target_train_ohe)
dummy_pred = model.predict(features_test_ohe)
fig, ax = plt.subplots(figsize=(6, 5))

# Usamos la función para graficar nuestros resultados

plot_roc(
    custom_axis= ax,
    y= target_test_ohe,
    predictions= dummy_pred
)

fig.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# ### DecissionTree

# %%
# Usamos GridSearchCV para probar diferentes hyperparametros y encontrar el mejor modelo de árbol de decisión 

param_grid = {
    'max_depth':[None,2,5,10],
    'min_samples_split':[2,5],
    'min_samples_leaf':[1,2]
}

grid_search = GridSearchCV(
    estimator=DecisionTreeClassifier(
        random_state = random_state),
        param_grid=param_grid, 
        cv=5,
        scoring='roc_auc')

grid_search.fit(features_train_ohe, target_train_ohe)

best_params = grid_search.best_params_
best_score = grid_search.best_score_

best_model = grid_search.best_estimator_
predict_tree = best_model.predict(features_test_ohe)

print(best_model)
print(best_params)
print(best_score)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=12345)
# {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.8233904140482954

# %%
# Graficamos nuestro resultado

fig, ax = plt.subplots(figsize=(6, 5))

plot_roc(
    custom_axis= ax,
    y= target_test_ohe,
    predictions= predict_tree
)

fig.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# ### RadomForest

# %%
# Usamos GridSearchCV para probar diferentes hyperparametros y encontrar el mejor modelo de bosque aleatorio 

param_grid = {
    'n_estimators':[50,100,150],
    'max_depth':[None,3,5,7,9,11],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(
    estimator=RandomForestClassifier(
        random_state = random_state), 
        param_grid=param_grid, 
        cv=5, 
        scoring='roc_auc')

grid_search.fit(features_train_ohe, target_train_ohe)

best_params = grid_search.best_params_
best_score = grid_search.best_score_

best_model = grid_search.best_estimator_
predict_forest = best_model.predict(features_test_ohe)

print(best_model)
print(best_params)
print(best_score)
# Out:
# RandomForestClassifier(max_depth=7, n_estimators=150, random_state=12345)
# {'max_depth': 7, 'min_samples_split': 2, 'n_estimators': 150}
# 0.845386428955744

# %%
# Graficamos nuestro resultado

fig, ax = plt.subplots(figsize=(6, 5))

plot_roc(
    custom_axis= ax,
    y= target_test_ohe,
    predictions= predict_forest
)

fig.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# ### LogisticRegression ClassWeight

# %%
# Usamos GridSearchCV para probar diferentes hyperparametros y encontrar el mejor modelo de regresión logística

param_grid = {
    'penalty': ['l1', 'l2'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
}

grid_search = GridSearchCV(
    estimator=LogisticRegression(
        class_weight = 'balanced', max_iter = 5000, solver = 'liblinear'), 
        param_grid=param_grid, 
        cv=5, 
        scoring='roc_auc')

grid_search.fit(features_train_ohe, target_train_ohe)

best_params = grid_search.best_params_
best_score = grid_search.best_score_

best_model = grid_search.best_estimator_
predict_lr = best_model.predict(features_test_ohe)

print(best_model)
print(best_params)
print(best_score)
# Out:
# LogisticRegression(C=0.1, class_weight='balanced', max_iter=5000,
#                    solver='liblinear')
# {'C': 0.1, 'penalty': 'l2'}
# 0.8364080376136089

# %%
# Graficamos nuestros resultados

fig, ax = plt.subplots(figsize=(6, 5))

plot_roc(
    custom_axis= ax,
    y= target_test_ohe,
    predictions= predict_lr
)

fig.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# ### LightGBM

# %%
# Creamos un modelo lightgbm

train_data = lgb.Dataset(features_train_ohe,label=target_train_ohe)
test_data = lgb.Dataset(features_test_ohe,label=target_test_ohe)
params = {
    'objective': 'binary',  
    'metric': 'binary_logloss', 
    'boosting_type': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9
}
num_round = 100
bts = lgb.train(params, train_data, num_round, valid_sets=[test_data])
lgb_predict = bts.predict(features_test_ohe,num_iteration=bts.best_iteration)

# Graficamos nuestros resultados

fig, ax = plt.subplots(figsize=(6, 5))

plot_roc(
    custom_axis= ax,
    y= target_test_ohe,
    predictions= lgb_predict
)

fig.tight_layout(pad=3.0)
plt.show()
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 1486, number of negative: 4139
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000923 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 550
# [LightGBM] [Info] Number of data points in the train set: 5625, number of used features: 22
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.264178 -> initscore=-1.024366
# [LightGBM] [Info] Start training from score -1.024366

# %% [markdown]
# #### CatBoost

# %%
# Usamos GridSearchCV para probar diferentes hyperparametros y encontrar el mejor modelo CatBoost

param_grid = {
     'learning_rate': [0.01, 0.1, 0.2],
    'depth': [4, 6, 8],
    'n_estimators': [50, 100, 200],
}

grid_search = GridSearchCV(
    estimator=CatBoostClassifier(),
        param_grid=param_grid, 
        cv=5, 
        scoring='roc_auc')

grid_search.fit(features_train_ohe, target_train_ohe)

best_params = grid_search.best_params_
best_score = grid_search.best_score_

best_model = grid_search.best_estimator_
predict_cb = best_model.predict(features_test_ohe)

print(best_model)
print(best_params)
print(best_score)
# Out:
# 0:	learn: 0.6864288	total: 3.31ms	remaining: 162ms
# 1:	learn: 0.6808082	total: 6.52ms	remaining: 157ms
# 2:	learn: 0.6757092	total: 9.84ms	remaining: 154ms
# 3:	learn: 0.6693344	total: 13ms	remaining: 150ms
# 4:	learn: 0.6642152	total: 16.2ms	remaining: 146ms
# 5:	learn: 0.6597483	total: 19.5ms	remaining: 143ms
# 6:	learn: 0.6539078	total: 22.6ms	remaining: 139ms
# 7:	learn: 0.6483669	total: 26.1ms	remaining: 137ms
# 8:	learn: 0.6426785	total: 29.4ms	remaining: 134ms
# 9:	learn: 0.6380568	total: 32.6ms	remaining: 130ms
# 10:	learn: 0.6348172	total: 35.7ms	remaining: 127ms
# 11:	learn: 0.6302992	total: 39ms	remaining: 124ms
# 12:	learn: 0.6264530	total: 42.3ms	remaining: 120ms
# 13:	learn: 0.6223672	total: 45.6ms	remaining: 117ms
# 14:	learn: 0.6171944	total: 48.7ms	remaining: 114ms
# 15:	learn: 0.6123931	total: 52.2ms	remaining: 111ms
# 16:	learn: 0.6075169	total: 56.5ms	remaining: 110ms
# 17:	learn: 0.6034506	total: 60.3ms	remaining: 107ms
# ...

# %%
# Graficamos nuestro resultado

fig, ax = plt.subplots(figsize=(6, 5))

plot_roc(
    custom_axis= ax,
    y= target_test_ohe,
    predictions= predict_cb
)

fig.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# #### Neural Networks

# %%
# Creamos un modelo de redes neuronales sencillo 

model = Sequential()
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(
    features_train_ohe, target_train_ohe, epochs=10, batch_size=32, validation_data=(features_test_ohe, target_test_ohe))
neu_net_predict = model.predict(features_test_ohe)

# Graficamos nuestro resultado

fig, ax = plt.subplots(figsize=(6, 5))

plot_roc(
    custom_axis= ax,
    y= target_test_ohe,
    predictions= neu_net_predict
)

fig.tight_layout(pad=3.0)
plt.show()
# Out:
# Epoch 1/10
# 176/176 [==============================] - 3s 6ms/step - loss: 2.1448 - accuracy: 0.6946 - val_loss: 1.3697 - val_accuracy: 0.7598
# Epoch 2/10
# 176/176 [==============================] - 1s 3ms/step - loss: 1.0447 - accuracy: 0.7355 - val_loss: 0.8337 - val_accuracy: 0.7733
# Epoch 3/10
# 176/176 [==============================] - 1s 3ms/step - loss: 1.0986 - accuracy: 0.7351 - val_loss: 0.6921 - val_accuracy: 0.7918
# Epoch 4/10
# 176/176 [==============================] - 1s 3ms/step - loss: 1.3467 - accuracy: 0.7364 - val_loss: 0.9396 - val_accuracy: 0.7846
# Epoch 5/10
# 176/176 [==============================] - 1s 3ms/step - loss: 1.3318 - accuracy: 0.7426 - val_loss: 0.9723 - val_accuracy: 0.7719
# Epoch 6/10
# 176/176 [==============================] - 0s 3ms/step - loss: 0.9186 - accuracy: 0.7524 - val_loss: 0.7057 - val_accuracy: 0.7903
# Epoch 7/10
# ...

# %% [markdown]
# **Conclusiones Primeros Modelos**
#
# **Dummy**
# - Roc_Auc 0.5
#
#
# **DecisionTree**
# - Best Params: max_depth 5, min_samples_leaf 1, min_samples_split 2
# - Roc_Auc training: 0.823
# - Roc_Auc test: 0.691
#
# **RandomForest**
# - Best Params: max_depth 7, min_samples_leaf 2, n_estimators 150
# - Roc_Auc training: 0.845
# - Roc_Auc test: 0.68
#
# **LogisticRegression**
# - Best Params: C 0.1, class_weight “Balanced”, max_iter 5000, penalty L2
# - Roc_Auc training: 0.836
# - Roc_Auc test: 0.759
#
# **LightGBM**
# - Params: 'objective': 'binary', 'metric': 'binary_logloss',  'boosting_type': 'gbdt', 'num_leaves': 31, 'learning_rate': 0.05, 'feature_fraction': 0.9
# - Roc_Auc test: 0.846
#
# **CatBoost**
# - Best Params: depth 4, learning_rate 0.1, n_estimators 50
# - Roc_Auc training: 0.848
# - Roc_Auc test: 0.704
#
# **Neural Network**
# - Roc_Auc test: 0.744
#
#
# El mejor de todos nuestros primeros modelos es el modelo LighGbm con un roc_auc de 0.846 en el set de prueba.

# %% [markdown]
# ## Modelos Upsumple

# %%
# Creamos una función para usar el método de sobre muestro en nuestro conjunto de datos.

def upsample(features, target, repeat):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)

    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=12345
    )

    return features_upsampled, target_upsampled

features_upsample_ohe, target_upsample_ohe = upsample(
    features_train_ohe, target_train_ohe, 10
)

# %%
# Creamos nuestros conjuntos de entrenamiento y prueba

features_train_oheu, features_test_oheu, target_train_oheu, target_test_oheu = train_test_split(
    features_upsample_ohe, target_upsample_ohe, test_size = 0.2, random_state=random_state)

# %% [markdown]
# #### Dummy Upsample

# %%
# Creamos nuestro modelo dummy

model = DummyClassifier(strategy='most_frequent')
model.fit(features_train_oheu, target_train_oheu)
dummy_predu = model.predict(features_test_oheu)

fig, ax = plt.subplots(figsize=(6, 5))

plot_roc(
    custom_axis= ax,
    y= target_test_oheu,
    predictions= dummy_predu
)

fig.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# ### DecissionTree Upsample

# %%
# Creamos nuestro modelo de árbol de decisión

param_grid = {
    'max_depth':[None,3,5,7,9,11],
    'min_samples_split':[2,4,6,8],
    'min_samples_leaf':[2,4,6]
}

grid_search = GridSearchCV(
    estimator=DecisionTreeClassifier(
        random_state = random_state),
        param_grid=param_grid, 
        cv=5,
        scoring='roc_auc')

grid_search.fit(features_train_oheu, target_train_oheu)

best_params = grid_search.best_params_
best_score = grid_search.best_score_

best_model = grid_search.best_estimator_
predict_treeu = best_model.predict(features_test_oheu)

print(best_model)
print(best_params)
print(best_score)
# Out:
# DecisionTreeClassifier(min_samples_leaf=2, min_samples_split=8,
#                        random_state=12345)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 8}
# 0.883553507367337

# %%
# Graficamos nuestros resultados

fig, ax = plt.subplots(figsize=(6, 5))

plot_roc(
    custom_axis= ax,
    y= target_test_oheu,
    predictions= predict_treeu
)

fig.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# ### RandomForest Upsample

# %%
# Creamos nuestro modelo random forest

param_grid = {
    'n_estimators':[20,40,50,100,],
    'max_depth':[None,3,5,7,9,11],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(
    estimator=RandomForestClassifier(
        random_state = random_state), 
        param_grid=param_grid, cv=5, 
        scoring='roc_auc')

grid_search.fit(features_train_oheu, target_train_oheu)

best_params = grid_search.best_params_
best_score = grid_search.best_score_

best_model = grid_search.best_estimator_
predict_forestu = best_model.predict(features_test_oheu)

print(best_model)
print(best_params)
print(best_score)
# Out:
# RandomForestClassifier(random_state=12345)
# {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}
# 0.9947767701675811

# %%
# Graficamos nuestros resultados

fig, ax = plt.subplots(figsize=(6, 5))

plot_roc(
    custom_axis= ax,
    y= target_test_oheu,
    predictions= predict_forestu
)

fig.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# ### LogisticRegression Upsample

# %%
# Creamos nuestro modelo de regresion logistica

param_grid = {
     'penalty': ['l1', 'l2'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100]
}

grid_search = GridSearchCV(
    estimator=LogisticRegression(
        max_iter = 5000, solver = 'liblinear'), 
        param_grid=param_grid, 
        cv=5, 
        scoring='roc_auc')

grid_search.fit(features_train_oheu, target_train_oheu)

best_params = grid_search.best_params_
best_score = grid_search.best_score_

best_model = grid_search.best_estimator_
predict_lru = best_model.predict(features_test_oheu)

print(best_model)
print(best_params)
print(best_score)
# Out:
# LogisticRegression(C=0.1, max_iter=5000, solver='liblinear')
# {'C': 0.1, 'penalty': 'l2'}
# 0.8382938671316446

# %%
# Graficamos nuestros resultados

fig, ax = plt.subplots(figsize=(6, 5))

plot_roc(
    custom_axis= ax,
    y= target_test_oheu,
    predictions= predict_lru
)

fig.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# #### LightGBM Upsample

# %%
# Creamos nuestro modelo Lightgbm 

train_data = lgb.Dataset(features_train_oheu,label=target_train_oheu)
test_data = lgb.Dataset(features_test_oheu,label=target_test_oheu)
params = {
    'objective': 'binary',  
    'metric': 'binary_logloss', 
    'boosting_type': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9
}
num_round = 100
bts = lgb.train(params, train_data, num_round, valid_sets=[test_data])
lgb_predictu = bts.predict(features_test_oheu,num_iteration=bts.best_iteration)

# Graficamos nuestros resultados

fig, ax = plt.subplots(figsize=(6, 5))

plot_roc(
    custom_axis= ax,
    y= target_test_oheu,
    predictions= lgb_predictu
)

fig.tight_layout(pad=3.0)
plt.show()
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 11914, number of negative: 3285
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002104 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 550
# [LightGBM] [Info] Number of data points in the train set: 15199, number of used features: 22
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.783867 -> initscore=1.288348
# [LightGBM] [Info] Start training from score 1.288348

# %% [markdown]
# #### CatBoost Upsample

# %%
# Creamos nuestro modelo CatBoost
param_grid = {
     'learning_rate': [0.01, 0.1, 0.2],
    'depth': [4, 6, 8],
    'n_estimators': [50, 100, 200],
}

grid_search = GridSearchCV(
    estimator=CatBoostClassifier(),
        param_grid=param_grid, 
        cv=5, 
        scoring='roc_auc')

grid_search.fit(features_train_oheu, target_train_oheu)

best_params = grid_search.best_params_
best_score = grid_search.best_score_

best_model = grid_search.best_estimator_
predict_cbu = best_model.predict(features_test_oheu)

print(best_model)
print(best_params)
print(best_score)
# Out:
# 0:	learn: 0.6857752	total: 4.76ms	remaining: 233ms
# 1:	learn: 0.6788152	total: 10ms	remaining: 240ms
# 2:	learn: 0.6722260	total: 14.7ms	remaining: 230ms
# 3:	learn: 0.6658700	total: 20.1ms	remaining: 231ms
# 4:	learn: 0.6590385	total: 24.4ms	remaining: 220ms
# 5:	learn: 0.6523844	total: 29.9ms	remaining: 219ms
# 6:	learn: 0.6460583	total: 34.4ms	remaining: 212ms
# 7:	learn: 0.6398308	total: 39.5ms	remaining: 208ms
# 8:	learn: 0.6333643	total: 45.1ms	remaining: 205ms
# 9:	learn: 0.6275523	total: 49.9ms	remaining: 200ms
# 10:	learn: 0.6217213	total: 54.5ms	remaining: 193ms
# 11:	learn: 0.6161249	total: 59.2ms	remaining: 187ms
# 12:	learn: 0.6105722	total: 64.1ms	remaining: 183ms
# 13:	learn: 0.6050724	total: 69.4ms	remaining: 178ms
# 14:	learn: 0.6000944	total: 74.1ms	remaining: 173ms
# 15:	learn: 0.5945714	total: 79.3ms	remaining: 169ms
# 16:	learn: 0.5894454	total: 83.6ms	remaining: 162ms
# 17:	learn: 0.5844458	total: 88.1ms	remaining: 157ms
# ...

# %%
# Graficamos nuestros resultados

fig, ax = plt.subplots(figsize=(6, 5))

plot_roc(
    custom_axis= ax,
    y= target_test_oheu,
    predictions= predict_cbu
)

fig.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# #### Neural Network

# %%
# Creamos nuestro modelo de redes neuronales

model = Sequential()
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(
    features_train_oheu, target_train_oheu, epochs = 10, batch_size= 32,validation_data=(features_test_oheu, target_test_oheu))

neu_net_predict = model.predict(features_test_oheu)

# Graficamos nuestros resultados

fig, ax = plt.subplots(figsize=(6, 5))

plot_roc(
    custom_axis= ax,
    y= target_test_oheu,
    predictions= neu_net_predict
)

fig.tight_layout(pad=3.0)
plt.show()
# Out:
# Epoch 1/10
# 475/475 [==============================] - 3s 3ms/step - loss: 3.1924 - accuracy: 0.7460 - val_loss: 1.3337 - val_accuracy: 0.7892
# Epoch 2/10
# 475/475 [==============================] - 1s 2ms/step - loss: 1.9469 - accuracy: 0.7677 - val_loss: 0.5979 - val_accuracy: 0.8182
# Epoch 3/10
# 475/475 [==============================] - 1s 3ms/step - loss: 2.2871 - accuracy: 0.7695 - val_loss: 0.9486 - val_accuracy: 0.8039
# Epoch 4/10
# 475/475 [==============================] - 1s 3ms/step - loss: 1.4921 - accuracy: 0.7827 - val_loss: 0.5044 - val_accuracy: 0.8242
# Epoch 5/10
# 475/475 [==============================] - 1s 3ms/step - loss: 1.5387 - accuracy: 0.7848 - val_loss: 1.6424 - val_accuracy: 0.7971
# Epoch 6/10
# 475/475 [==============================] - 2s 3ms/step - loss: 1.3182 - accuracy: 0.7893 - val_loss: 0.4851 - val_accuracy: 0.8213
# Epoch 7/10
# ...

# %% [markdown]
# **Conclusiones Modelos Upsumple**
#
# **Dummy**
# - Roc_Auc: 0.5
#
# **DecisionTree**
# - Best Params: max_depth None, min_samples_leaf 2 min_samples_split 8
# - Roc_Auc training: 0.883
# - Roc_Auc test: 0.87
#
# **RandomForest**
# - Best Params: max_depth None, min_samples_leaf 2, n_estimators 100
# - Roc_Auc training: 0.994
# - Roc_Auc test: 0.892
#
# **LogisticRegression**
# - Best Params: C 0.1, class_weight “Balanced”, max_iter 5000, penalty L2, solver “Liblinear”
# - Roc_Auc training: 0.838
# - Roc_Auc test: 0.691
#
# **LightGBM**
# - Params: 'objective': 'binary', 'metric': 'binary_logloss',  'boosting_type': 'gbdt', 'num_leaves': 31, 'learning_rate': 0.05, 'feature_fraction': 0.9
# - Roc_Auc test: 0.888
#
# **CatBoost**
# - Best Params: depth 8, learning_rate 0.2, n_estimators 200
# - Roc_Auc training: 0.95
# - Roc_Auc test: 0.849
#
# **Neural Network**
# - Roc_Auc test: 0.79
#
#
# Al utilizar el método de sobre muestro en nuestro conjunto de datos hemos logrado resultados mucho mejores en casi todos nuestros modelos. Está claro que el desbalanceo de clases afectaba a nuestros modelos. En casi todos los modelos hemos logrado buenos resultados. El mejor modelo fue el bosque aleatorio con sobre muestro y un ROC_AUC de 0.892 en el conjunto de prueba.
